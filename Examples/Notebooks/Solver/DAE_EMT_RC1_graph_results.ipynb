# %%
# %%bash
# mkdir -p logs
# /home/mmo/git/dpsim/build/Examples/Cxx/DAE_EMT_RC1
# Out:
# [00:24:35.935199 DAE_EMT_VS_RC1_console info] Opening interfaces.
# [00:24:35.935229 DAE_EMT_VS_RC1_console info] Start simulation: DAE_EMT_VS_RC1
# Start simulation: DAE_EMT_VS_RC1
# [00:24:39.510810 DAE_EMT_VS_RC1_console info] Simulation finished.

# %%
# read Simulink log file

import os
print(os.getcwd())

import matplotlib.pyplot as plt
import villas.dataprocessing.readtools as rt

# read EMT results
log_name = 'logs/DAE_EMT_VS_RC1/DAE_EMT_VS_RC1.csv'
ts_dpsim_emt = rt.read_timeseries_dpsim(log_name)

plt.figure(1)
plt.plot(ts_dpsim_emt['v1'].time, ts_dpsim_emt['v1'].values, label='v1 EMT')
plt.plot(ts_dpsim_emt['v2'].time, ts_dpsim_emt['v2'].values, label='v2 EMT')
plt.legend(loc='lower right')
plt.figure(2)
plt.plot(ts_dpsim_emt['i_c1'].time, ts_dpsim_emt['i_c1'].values, label='i_c EMT')
plt.legend(loc='lower right')
plt.show()
# Out:
# /home/mmo/git/dpsim/build/Examples/Cxx
# column number: 8
# results length: 1000
# real column names: ['i_c1', 'i_r', 'i_vs', 'v1', 'v2', 'v_c1', 'vr', 'vs']
# complex column names: []
