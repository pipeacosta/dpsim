# %%
# %%bash
# mkdir -p logs
# TOP=${TOP:-$(git rev-parse --show-toplevel)}
# PATH=${TOP}/build/Examples/Cxx
# ${PATH}/DAE_EMT_RL1
# Out:
# [20:26:19.530708 DAE_EMT_VS_RL1_console info] Opening interfaces.
# [20:26:19.530741 DAE_EMT_VS_RL1_console info] Start simulation: DAE_EMT_VS_RL1
# Start simulation: DAE_EMT_VS_RL1
# [20:26:19.843035 DAE_EMT_VS_RL1_console info] Simulation finished.
# [*** LOG ERROR ***] [2020-05-21 20:26:19] [vs] invalid type specifier
# [*** LOG ERROR ***] [2020-05-21 20:26:19] [l_1] invalid type specifier

# %%
# read Simulink log file

import matplotlib.pyplot as plt
import villas.dataprocessing.readtools as rt

# read EMT results
log_name = 'logs/DAE_EMT_VS_RL1/DAE_EMT_VS_RL1.csv'
ts_dpsim_emt = rt.read_timeseries_dpsim(log_name)

plt.figure(1)
plt.plot(ts_dpsim_emt['v1'].time, ts_dpsim_emt['v1'].values, label='v1 EMT')
plt.plot(ts_dpsim_emt['v2'].time, ts_dpsim_emt['v2'].values, label='v2 EMT')
plt.legend(loc='lower right')
plt.figure(2)
plt.plot(ts_dpsim_emt['i_l1'].time, ts_dpsim_emt['i_l1'].values, label='i_l EMT')
plt.legend(loc='lower right')
plt.show()
# Out:
# column number: 8
# results length: 1000
# real column names: ['i_l1', 'i_r', 'i_vs', 'v1', 'v2', 'v_l1', 'vr', 'vs']
# complex column names: []
