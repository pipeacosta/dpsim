# %%
# %%bash
# mkdir -p logs
# /home/mmo/git/dpsim/build/Examples/Cxx/DAE_EMT_RL1
# Out:
# [08:15:03.980335 DAE_EMT_VS_RL1_console info] Opening interfaces.
# [08:15:03.980374 DAE_EMT_VS_RL1_console info] Start simulation: DAE_EMT_VS_RL1
# Start simulation: DAE_EMT_VS_RL1
# [08:15:04.369753 DAE_EMT_VS_RL1_console info] Simulation finished.
# [*** LOG ERROR ***] [2020-04-27 08:15:03] [vs] invalid type specifier
# [*** LOG ERROR ***] [2020-04-27 08:15:03] [l_1] invalid type specifier

# %%
# read Simulink log file

import matplotlib.pyplot as plt
import villas.dataprocessing.readtools as rt

# read EMT results
log_name = 'logs/DAE_EMT_VS_RL1/DAE_EMT_VS_RL1.csv'
ts_dpsim_emt = rt.read_timeseries_dpsim(log_name)

plt.figure(1)
plt.plot(ts_dpsim_emt['v1'].time, ts_dpsim_emt['v1'].values, label='v1 EMT')
plt.plot(ts_dpsim_emt['v2'].time, ts_dpsim_emt['v2'].values, label='v2 EMT')
plt.legend(loc='lower right')
plt.figure(2)
plt.plot(ts_dpsim_emt['i_l1'].time, ts_dpsim_emt['i_l1'].values, label='i_l EMT')
plt.legend(loc='lower right')
plt.show()
# Out:
# column number: 8
# results length: 1000
# real column names: ['i_l1', 'i_r', 'i_vs', 'v1', 'v2', 'v_l1', 'vr', 'vs']
# complex column names: []
