# %%
# %%bash
# mkdir -p logs
# /home/mmo/git/dpsim/build/Examples/Cxx/DAE_EMT_RLC1
# Out:
# [08:09:54.736575 DAE_EMT_RLC1_console info] Opening interfaces.
# [08:09:54.736609 DAE_EMT_RLC1_console info] Start simulation: DAE_EMT_RLC1
# Start simulation: DAE_EMT_RLC1
# [08:09:55.186092 DAE_EMT_RLC1_console info] Simulation finished.
# [*** LOG ERROR ***] [2020-04-27 08:09:54] [vs] invalid type specifier

# %%
# read Simulink log file

import os
print(os.getcwd())

import matplotlib.pyplot as plt
import villas.dataprocessing.readtools as rt

# read EMT results
log_name = 'logs/DAE_EMT_RLC1/DAE_EMT_RLC1.csv'
ts_dpsim_emt = rt.read_timeseries_dpsim(log_name)

plt.figure(1)
plt.plot(ts_dpsim_emt['v_l'].time, ts_dpsim_emt['v_l'].values, label='v_l EMT')
plt.plot(ts_dpsim_emt['v_c'].time, ts_dpsim_emt['v_c'].values, label='v_c EMT')
plt.plot(ts_dpsim_emt['v_r'].time, ts_dpsim_emt['v_r'].values, label='v_r EMT')
plt.legend(loc='lower right')
plt.figure(2)
plt.plot(ts_dpsim_emt['i_c1'].time, ts_dpsim_emt['i_c1'].values, label='i EMT')
plt.legend(loc='lower right')
plt.show()
# Out:
# /home/mmo/git/dpsim/Examples/Notebooks/Solver
# column number: 4
# results length: 1000
# real column names: ['i_c1', 'v_c', 'v_l', 'v_r']
# complex column names: []
