# %% [markdown]
# ## Run

# %% [markdown]
# ### Split system in EMT, using decoupling node

# %%
# %%bash
# TOP=${TOP:-$(git rev-parse --show-toplevel)}
# PATH=${TOP}/build/dpsim/examples/cxx
#
# # Define lists for timestep and prefix
# delays=(0.0001, 0.0002, 0.0004, 0.001, 0.003, 0.01)
# prefixes=(linear_1e-4 linear_2e-4 linear_4e-4 linear_0.001 linear_0.003 linear_0.01)
# i_intfs=(30.1080 30.216 30.432 31.08 33.24 40.8)
#
# # Iterate over the lists
# for i in "${!delays[@]}"; do
#   EMT_RC_split_decoupled_node_DC --timestep=0.00005 -o delay="${delays[$i]}" -o method=extrapolation-linear -o i-intf-0="${i_intfs[$i]}" -o prefix="${prefixes[$i]}"
# done
# Out:
# Simulate with 0 threads, sequence number 0, co-simulation method extrapolation-linear
# [13:50:43.766918 EMT_RC_monolithic info] Initialize simulation: EMT_RC_monolithic
# [13:50:43.767055 MnaSolverFactory info] creating KLUAdapter solver implementation
# [13:50:43.767534 EMT_RC_monolithic info] Scheduling tasks.
# [13:50:43.767824 EMT_RC_monolithic info] Scheduling done.
# [13:50:43.768153 EMT_RC_monolithic info] Opening interfaces.
# [13:50:43.768156 EMT_RC_monolithic info] Start synchronization with remotes on interfaces
# [13:50:43.768157 EMT_RC_monolithic info] Synchronized simulation start with remotes
# [13:50:43.768160 EMT_RC_monolithic info] Start simulation: EMT_RC_monolithic
# [13:50:43.768163 EMT_RC_monolithic info] Time step: 5.000000e-05
# [13:50:43.768165 EMT_RC_monolithic info] Final time: 1.200000e+00
# Detected 1 subnets
# [13:50:44.043574 EMT_RC_monolithic info] Simulation calculation time: 0.275373
# [13:50:44.043635 EMT_RC_monolithic info] Simulation finished.
# [13:50:44.052594 EMT_RC_monolithic info] Average step time: 0.000011284
# [13:50:44.053555 EMT_RC_split_decoupled_linear_1e-4_0_0 info] Initialize simulation: EMT_RC_split_decoupled_linear_1e-4_0_0
# [13:50:44.053677 MnaSolverFactory info] creating KLUAdapter solver implementation
# [13:50:44.054044 MnaSolverFactory info] creating KLUAdapter solver implementation
# [13:50:44.054218 EMT_RC_split_decoupled_linear_1e-4_0_0 info] Scheduling tasks.
# Detected 2 subnets
# mCur1Extrap: 30.108 30
# [13:50:44.054584 EMT_RC_split_decoupled_linear_1e-4_0_0 info] Scheduling done.
# [13:50:44.055211 EMT_RC_split_decoupled_linear_1e-4_0_0 info] Opening interfaces.
# [13:50:44.055215 EMT_RC_split_decoupled_linear_1e-4_0_0 info] Start synchronization with remotes on interfaces
# [13:50:44.055217 EMT_RC_split_decoupled_linear_1e-4_0_0 info] Synchronized simulation start with remotes
# [13:50:44.055220 EMT_RC_split_decoupled_linear_1e-4_0_0 info] Start simulation: EMT_RC_split_decoupled_linear_1e-4_0_0
# [13:50:44.055223 EMT_RC_split_decoupled_linear_1e-4_0_0 info] Time step: 5.000000e-05
# [13:50:44.055226 EMT_RC_split_decoupled_linear_1e-4_0_0 info] Final time: 1.200000e+00
# [13:50:44.512865 EMT_RC_split_decoupled_linear_1e-4_0_0 info] Simulation calculation time: 0.457604
# [13:50:44.512912 EMT_RC_split_decoupled_linear_1e-4_0_0 info] Simulation finished.
# [13:50:44.521860 EMT_RC_split_decoupled_linear_1e-4_0_0 info] Average step time: 0.000018894
# Simulate with 0 threads, sequence number 0, co-simulation method extrapolation-linear
# [13:50:44.544353 EMT_RC_monolithic info] Initialize simulation: EMT_RC_monolithic
# [13:50:44.544466 MnaSolverFactory info] creating KLUAdapter solver implementation
# [13:50:44.544837 EMT_RC_monolithic info] Scheduling tasks.
# [13:50:44.545085 EMT_RC_monolithic info] Scheduling done.
# [13:50:44.545447 EMT_RC_monolithic info] Opening interfaces.
# [13:50:44.545450 EMT_RC_monolithic info] Start synchronization with remotes on interfaces
# [13:50:44.545451 EMT_RC_monolithic info] Synchronized simulation start with remotes
# [13:50:44.545454 EMT_RC_monolithic info] Start simulation: EMT_RC_monolithic
# [13:50:44.545457 EMT_RC_monolithic info] Time step: 5.000000e-05
# [13:50:44.545459 EMT_RC_monolithic info] Final time: 1.200000e+00
# Detected 1 subnets
# [13:50:44.796406 EMT_RC_monolithic info] Simulation calculation time: 0.250915
# [13:50:44.804933 EMT_RC_monolithic info] Simulation finished.
# [13:50:44.816082 EMT_RC_monolithic info] Average step time: 0.000010282
# [13:50:44.817146 EMT_RC_split_decoupled_linear_2e-4_0_0 info] Initialize simulation: EMT_RC_split_decoupled_linear_2e-4_0_0
# [13:50:44.817307 MnaSolverFactory info] creating KLUAdapter solver implementation
# Detected 2 subnets
# mCur1Extrap: 30.216 30
# [13:50:44.817725 MnaSolverFactory info] creating KLUAdapter solver implementation
# [13:50:44.817904 EMT_RC_split_decoupled_linear_2e-4_0_0 info] Scheduling tasks.
# [13:50:44.818278 EMT_RC_split_decoupled_linear_2e-4_0_0 info] Scheduling done.
# [13:50:44.818896 EMT_RC_split_decoupled_linear_2e-4_0_0 info] Opening interfaces.
# [13:50:44.818899 EMT_RC_split_decoupled_linear_2e-4_0_0 info] Start synchronization with remotes on interfaces
# [13:50:44.818901 EMT_RC_split_decoupled_linear_2e-4_0_0 info] Synchronized simulation start with remotes
# [13:50:44.818904 EMT_RC_split_decoupled_linear_2e-4_0_0 info] Start simulation: EMT_RC_split_decoupled_linear_2e-4_0_0
# [13:50:44.818907 EMT_RC_split_decoupled_linear_2e-4_0_0 info] Time step: 5.000000e-05
# [13:50:44.818909 EMT_RC_split_decoupled_linear_2e-4_0_0 info] Final time: 1.200000e+00
# [13:50:45.267579 EMT_RC_split_decoupled_linear_2e-4_0_0 info] Simulation calculation time: 0.448639
# [13:50:45.277338 EMT_RC_split_decoupled_linear_2e-4_0_0 info] Simulation finished.
# [13:50:45.286298 EMT_RC_split_decoupled_linear_2e-4_0_0 info] Average step time: 0.000018522
# Simulate with 0 threads, sequence number 0, co-simulation method extrapolation-linear
# [13:50:45.309701 EMT_RC_monolithic info] Initialize simulation: EMT_RC_monolithic
# [13:50:45.309837 MnaSolverFactory info] creating KLUAdapter solver implementation
# [13:50:45.310318 EMT_RC_monolithic info] Scheduling tasks.
# [13:50:45.310568 EMT_RC_monolithic info] Scheduling done.
# Detected 1 subnets
# [13:50:45.310866 EMT_RC_monolithic info] Opening interfaces.
# [13:50:45.310870 EMT_RC_monolithic info] Start synchronization with remotes on interfaces
# [13:50:45.310871 EMT_RC_monolithic info] Synchronized simulation start with remotes
# [13:50:45.310874 EMT_RC_monolithic info] Start simulation: EMT_RC_monolithic
# [13:50:45.310877 EMT_RC_monolithic info] Time step: 5.000000e-05
# [13:50:45.310879 EMT_RC_monolithic info] Final time: 1.200000e+00
# [13:50:45.582666 EMT_RC_monolithic info] Simulation calculation time: 0.271755
# [13:50:45.582724 EMT_RC_monolithic info] Simulation finished.
# [13:50:45.591579 EMT_RC_monolithic info] Average step time: 0.000011139
# [13:50:45.592526 EMT_RC_split_decoupled_linear_4e-4_0_0 info] Initialize simulation: EMT_RC_split_decoupled_linear_4e-4_0_0
# [13:50:45.592661 MnaSolverFactory info] creating KLUAdapter solver implementation
# [13:50:45.593092 MnaSolverFactory info] creating KLUAdapter solver implementation
# Detected 2 subnets
# mCur1Extrap: 30.432 30
# [13:50:45.593268 EMT_RC_split_decoupled_linear_4e-4_0_0 info] Scheduling tasks.
# [13:50:45.593614 EMT_RC_split_decoupled_linear_4e-4_0_0 info] Scheduling done.
# [13:50:45.594296 EMT_RC_split_decoupled_linear_4e-4_0_0 info] Opening interfaces.
# [13:50:45.594299 EMT_RC_split_decoupled_linear_4e-4_0_0 info] Start synchronization with remotes on interfaces
# [13:50:45.594300 EMT_RC_split_decoupled_linear_4e-4_0_0 info] Synchronized simulation start with remotes
# [13:50:45.594304 EMT_RC_split_decoupled_linear_4e-4_0_0 info] Start simulation: EMT_RC_split_decoupled_linear_4e-4_0_0
# [13:50:45.594306 EMT_RC_split_decoupled_linear_4e-4_0_0 info] Time step: 5.000000e-05
# [13:50:45.594309 EMT_RC_split_decoupled_linear_4e-4_0_0 info] Final time: 1.200000e+00
# [13:50:46.063688 EMT_RC_split_decoupled_linear_4e-4_0_0 info] Simulation calculation time: 0.469350
# [13:50:46.063739 EMT_RC_split_decoupled_linear_4e-4_0_0 info] Simulation finished.
# [13:50:46.072667 EMT_RC_split_decoupled_linear_4e-4_0_0 info] Average step time: 0.000019382
# Simulate with 0 threads, sequence number 0, co-simulation method extrapolation-linear
# [13:50:46.087145 EMT_RC_monolithic info] Initialize simulation: EMT_RC_monolithic
# [13:50:46.087255 MnaSolverFactory info] creating KLUAdapter solver implementation
# [13:50:46.088181 EMT_RC_monolithic info] Scheduling tasks.
# Detected 1 subnets
# [13:50:46.088443 EMT_RC_monolithic info] Scheduling done.
# [13:50:46.088827 EMT_RC_monolithic info] Opening interfaces.
# [13:50:46.088832 EMT_RC_monolithic info] Start synchronization with remotes on interfaces
# [13:50:46.088833 EMT_RC_monolithic info] Synchronized simulation start with remotes
# [13:50:46.088836 EMT_RC_monolithic info] Start simulation: EMT_RC_monolithic
# [13:50:46.088840 EMT_RC_monolithic info] Time step: 5.000000e-05
# [13:50:46.088842 EMT_RC_monolithic info] Final time: 1.200000e+00
# [13:50:46.340670 EMT_RC_monolithic info] Simulation calculation time: 0.251795
# [13:50:46.346582 EMT_RC_monolithic info] Simulation finished.
# [13:50:46.356083 EMT_RC_monolithic info] Average step time: 0.000010322
# [13:50:46.357051 EMT_RC_split_decoupled_linear_0.001_0_0 info] Initialize simulation: EMT_RC_split_decoupled_linear_0.001_0_0
# [13:50:46.357177 MnaSolverFactory info] creating KLUAdapter solver implementation
# [13:50:46.357561 MnaSolverFactory info] creating KLUAdapter solver implementation
# [13:50:46.357738 EMT_RC_split_decoupled_linear_0.001_0_0 info] Scheduling tasks.
# Detected 2 subnets
# mCur1Extrap: 31.08 30
# [13:50:46.358109 EMT_RC_split_decoupled_linear_0.001_0_0 info] Scheduling done.
# [13:50:46.359217 EMT_RC_split_decoupled_linear_0.001_0_0 info] Opening interfaces.
# [13:50:46.359221 EMT_RC_split_decoupled_linear_0.001_0_0 info] Start synchronization with remotes on interfaces
# [13:50:46.359223 EMT_RC_split_decoupled_linear_0.001_0_0 info] Synchronized simulation start with remotes
# [13:50:46.359226 EMT_RC_split_decoupled_linear_0.001_0_0 info] Start simulation: EMT_RC_split_decoupled_linear_0.001_0_0
# [13:50:46.359230 EMT_RC_split_decoupled_linear_0.001_0_0 info] Time step: 5.000000e-05
# [13:50:46.359232 EMT_RC_split_decoupled_linear_0.001_0_0 info] Final time: 1.200000e+00
# [13:50:46.809281 EMT_RC_split_decoupled_linear_0.001_0_0 info] Simulation calculation time: 0.450016
# [13:50:46.823381 EMT_RC_split_decoupled_linear_0.001_0_0 info] Simulation finished.
# [13:50:46.841191 EMT_RC_split_decoupled_linear_0.001_0_0 info] Average step time: 0.000018577
# Simulate with 0 threads, sequence number 0, co-simulation method extrapolation-linear
# [13:50:46.858509 EMT_RC_monolithic info] Initialize simulation: EMT_RC_monolithic
# [13:50:46.858621 MnaSolverFactory info] creating KLUAdapter solver implementation
# [13:50:46.859449 EMT_RC_monolithic info] Scheduling tasks.
# [13:50:46.859699 EMT_RC_monolithic info] Scheduling done.
# Detected 1 subnets
# [13:50:46.860011 EMT_RC_monolithic info] Opening interfaces.
# [13:50:46.860015 EMT_RC_monolithic info] Start synchronization with remotes on interfaces
# [13:50:46.860016 EMT_RC_monolithic info] Synchronized simulation start with remotes
# [13:50:46.860019 EMT_RC_monolithic info] Start simulation: EMT_RC_monolithic
# [13:50:46.860022 EMT_RC_monolithic info] Time step: 5.000000e-05
# [13:50:46.860024 EMT_RC_monolithic info] Final time: 1.200000e+00
# [13:50:47.115199 EMT_RC_monolithic info] Simulation calculation time: 0.255143
# [13:50:47.115261 EMT_RC_monolithic info] Simulation finished.
# [13:50:47.124268 EMT_RC_monolithic info] Average step time: 0.000010462
# [13:50:47.125262 EMT_RC_split_decoupled_linear_0.003_0_0 info] Initialize simulation: EMT_RC_split_decoupled_linear_0.003_0_0
# [13:50:47.125388 MnaSolverFactory info] creating KLUAdapter solver implementation
# Detected 2 subnets
# mCur1Extrap: 33.24 30
# [13:50:47.125778 MnaSolverFactory info] creating KLUAdapter solver implementation
# [13:50:47.125954 EMT_RC_split_decoupled_linear_0.003_0_0 info] Scheduling tasks.
# [13:50:47.126335 EMT_RC_split_decoupled_linear_0.003_0_0 info] Scheduling done.
# [13:50:47.127029 EMT_RC_split_decoupled_linear_0.003_0_0 info] Opening interfaces.
# [13:50:47.127033 EMT_RC_split_decoupled_linear_0.003_0_0 info] Start synchronization with remotes on interfaces
# [13:50:47.127034 EMT_RC_split_decoupled_linear_0.003_0_0 info] Synchronized simulation start with remotes
# [13:50:47.127037 EMT_RC_split_decoupled_linear_0.003_0_0 info] Start simulation: EMT_RC_split_decoupled_linear_0.003_0_0
# [13:50:47.127040 EMT_RC_split_decoupled_linear_0.003_0_0 info] Time step: 5.000000e-05
# [13:50:47.127042 EMT_RC_split_decoupled_linear_0.003_0_0 info] Final time: 1.200000e+00
# [13:50:47.592741 EMT_RC_split_decoupled_linear_0.003_0_0 info] Simulation calculation time: 0.465668
# [13:50:47.592791 EMT_RC_split_decoupled_linear_0.003_0_0 info] Simulation finished.
# [13:50:47.601690 EMT_RC_split_decoupled_linear_0.003_0_0 info] Average step time: 0.000019221
# Simulate with 0 threads, sequence number 0, co-simulation method extrapolation-linear
# [13:50:47.616134 EMT_RC_monolithic info] Initialize simulation: EMT_RC_monolithic
# [13:50:47.616250 MnaSolverFactory info] creating KLUAdapter solver implementation
# [13:50:47.617204 EMT_RC_monolithic info] Scheduling tasks.
# Detected 1 subnets
# [13:50:47.617453 EMT_RC_monolithic info] Scheduling done.
# [13:50:47.617850 EMT_RC_monolithic info] Opening interfaces.
# [13:50:47.617854 EMT_RC_monolithic info] Start synchronization with remotes on interfaces
# [13:50:47.617855 EMT_RC_monolithic info] Synchronized simulation start with remotes
# [13:50:47.617858 EMT_RC_monolithic info] Start simulation: EMT_RC_monolithic
# [13:50:47.617861 EMT_RC_monolithic info] Time step: 5.000000e-05
# [13:50:47.617863 EMT_RC_monolithic info] Final time: 1.200000e+00
# [13:50:47.864865 EMT_RC_monolithic info] Simulation calculation time: 0.246969
# [13:50:47.873673 EMT_RC_monolithic info] Simulation finished.
# [13:50:47.882702 EMT_RC_monolithic info] Average step time: 0.000010106
# [13:50:47.883653 EMT_RC_split_decoupled_linear_0.01_0_0 info] Initialize simulation: EMT_RC_split_decoupled_linear_0.01_0_0
# [13:50:47.883779 MnaSolverFactory info] creating KLUAdapter solver implementation
# [13:50:47.884169 MnaSolverFactory info] creating KLUAdapter solver implementation
# [13:50:47.884344 EMT_RC_split_decoupled_linear_0.01_0_0 info] Scheduling tasks.
# Detected 2 subnets
# mCur1Extrap: 40.8 30
# [13:50:47.884692 EMT_RC_split_decoupled_linear_0.01_0_0 info] Scheduling done.
# [13:50:47.885327 EMT_RC_split_decoupled_linear_0.01_0_0 info] Opening interfaces.
# [13:50:47.885332 EMT_RC_split_decoupled_linear_0.01_0_0 info] Start synchronization with remotes on interfaces
# [13:50:47.885334 EMT_RC_split_decoupled_linear_0.01_0_0 info] Synchronized simulation start with remotes
# [13:50:47.885336 EMT_RC_split_decoupled_linear_0.01_0_0 info] Start simulation: EMT_RC_split_decoupled_linear_0.01_0_0
# [13:50:47.885339 EMT_RC_split_decoupled_linear_0.01_0_0 info] Time step: 5.000000e-05
# [13:50:47.885341 EMT_RC_split_decoupled_linear_0.01_0_0 info] Final time: 1.200000e+00
# [13:50:48.326392 EMT_RC_split_decoupled_linear_0.01_0_0 info] Simulation calculation time: 0.441020
# [13:50:48.337139 EMT_RC_split_decoupled_linear_0.01_0_0 info] Simulation finished.
# [13:50:48.349207 EMT_RC_split_decoupled_linear_0.01_0_0 info] Average step time: 0.000018204

# %% [markdown]
# ## Validate Results

# %%
import villas.dataprocessing.readtools as rt
import villas.dataprocessing.plottools as pt
from villas.dataprocessing.timeseries import TimeSeries as ts
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib widget

H_v = np.array([1e-4, 2e-4, 4e-4, 0.001, 0.003, 0.01])
H_v_legends = ['1e-4', '2e-4', '4e-4', '0.001', '0.003', '0.01']
y_1_prev_H = [30.1080, 30.216, 30.432, 31.08, 33.24, 40.8]

results_emt = rt.read_timeseries_dpsim('logs/EMT_RC_monolithic/EMT_RC_monolithic.csv')

# results_emt_attributes_zoh_S1 = {}
# for H_v_leg in H_v_legends:
#     results_emt_attributes_zoh_S1[H_v_leg] = rt.read_timeseries_dpsim('logs/EMTCosimAttributes_zoh_' + H_v_leg + '_S1/S1.csv')

# results_emt_attributes_zoh_S2 = {}
# for H_v_leg in H_v_legends:
#     results_emt_attributes_zoh_S2[H_v_leg] = rt.read_timeseries_dpsim('logs/EMTCosimAttributes_zoh_' + H_v_leg + '_S2/S2.csv')

results_emt_itm_linear = {}
for H_v_leg in H_v_legends:
    results_emt_itm_linear[H_v_leg] = rt.read_timeseries_dpsim('logs/EMT_RC_split_decoupled_linear_' + H_v_leg + '_0_0/EMT_RC_split_decoupled_linear_' + H_v_leg + '_0_0.csv')

pt.set_timeseries_labels(results_emt['v_2'], 'v_2 - Monolithic')
pt.plot_timeseries('Co-simulation results - v_intf - linear', results_emt['v_2'])
plt.xlabel('t [s]')
plt.ylabel('Interface voltage')
plt.grid()

pt.set_timeseries_labels(results_emt['i_rline'], 'i_rline - Monolithic')
pt.plot_timeseries('Co-simulation results - i_intf - linear', results_emt['i_rline'])

for k, results_att_list in results_emt_itm_linear.items():
    pt.set_timeseries_labels(results_att_list['v_intf'], 'v_intf - S_1, linear')
    pt.plot_timeseries('Co-simulation results - v_intf - linear', results_att_list['v_intf'], '--')
    
    pt.set_timeseries_labels(results_att_list['i_intf'], 'i_intf - S_1, linear')
    pt.plot_timeseries('Co-simulation results - i_intf - linear', results_att_list['i_intf'], '--')

plt.xlabel('t [s]')
plt.ylabel('Interface current')
plt.grid()
plt.show()
# Out:
# column number: 3
# results length: 24001
# real column names: ['i_rline', 'v_1', 'v_2']
# complex column names: []
# column number: 8
# results length: 24001
# real column names: ['i_intf', 'i_ref', 'i_rline', 'v_1', 'v_2_1', 'v_2_2', 'v_intf', 'v_ref']
# complex column names: []
# column number: 8
# results length: 24001
# real column names: ['i_intf', 'i_ref', 'i_rline', 'v_1', 'v_2_1', 'v_2_2', 'v_intf', 'v_ref']
# complex column names: []
# column number: 8
# results length: 24001
# real column names: ['i_intf', 'i_ref', 'i_rline', 'v_1', 'v_2_1', 'v_2_2', 'v_intf', 'v_ref']
# complex column names: []
# column number: 8
# results length: 24001
# real column names: ['i_intf', 'i_ref', 'i_rline', 'v_1', 'v_2_1', 'v_2_2', 'v_intf', 'v_ref']
# complex column names: []
# column number: 8
# results length: 24001
# real column names: ['i_intf', 'i_ref', 'i_rline', 'v_1', 'v_2_1', 'v_2_2', 'v_intf', 'v_ref']
# complex column names: []
# column number: 8
# results length: 24001
# real column names: ['i_intf', 'i_ref', 'i_rline', 'v_1', 'v_2_1', 'v_2_2', 'v_intf', 'v_ref']
# complex column names: []
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# path_split_emt = 'logs/EMT_RC_split_decoupled_delay_0_0_0/'
# logName_split_emt = 'EMT_RC_split_decoupled_delay_0_0_0'
# logFilename_split_emt = path_split_emt + logName_split_emt + '.csv'
# print(logFilename_split_emt)

# path_mono_emt = 'logs/EMT_RC_monolithic/'
# logName_mono_emt = 'EMT_RC_monolithic'
# logFilename_mono_emt = path_mono_emt + logName_mono_emt + '.csv'
# print(logFilename_mono_emt)

# decoupled_emt_split = rt.read_timeseries_dpsim(logFilename_split_emt)
# mono_emt = rt.read_timeseries_dpsim(logFilename_mono_emt)

# pt.set_timeseries_labels(mono_emt['v_2'], 'v_2 Monolithic')
# pt.plot_timeseries('Co-simulation results - v_intf', mono_emt['v_2'])
# pt.set_timeseries_labels(decoupled_emt_split['v_2_1'], 'v_2 decoupled S1')
# pt.plot_timeseries('Co-simulation results - v_intf', decoupled_emt_split['v_2_1'], '--')
# pt.set_timeseries_labels(decoupled_emt_split['v_2_2'], 'v_2 decoupled S2')
# pt.plot_timeseries('Co-simulation results - v_intf', decoupled_emt_split['v_2_2'], '-.')
# # plt.title('WSCC-09 with 3 lines replaced by decoupling equivalents')
# plt.xlabel('Time [s]')
# plt.ylabel('Voltage [V]')

# plt.show()

# %%
# pt.set_timeseries_labels(mono_emt['i_rline'], 'i_rline Monolithic')
# pt.plot_timeseries('Co-simulation results - i_intf', mono_emt['i_rline'])
# pt.set_timeseries_labels(decoupled_emt_split['i_ref'], 'i_intf, decoupled')
# pt.plot_timeseries('Co-simulation results - i_intf', decoupled_emt_split['i_ref'], '--')
# plt.xlabel('Time [s]')
# plt.ylabel('Voltage [V]')

# plt.show()

# %%
time_step = 50e-6

global_error_zoh = []
global_error_linear = []
global_error_delay = []

ts_v1_m = results_emt['v_1']
ts_v2_m = results_emt['v_2']
ts_i_intf_m = results_emt['i_rline']

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(7, 6))

for i in range(0, len(H_v_legends)):    
    H = H_v[i]
    
    m = int(round(H/time_step))

    # ts_v1_zoh = results_emt_attributes_zoh_S1[H_v_legends[i]]['v_1']
    # ts_v2_zoh = results_emt_attributes_zoh_S1[H_v_legends[i]]['v_2']
    # ts_i_intf_zoh = results_emt_attributes_zoh_S1[H_v_legends[i]]['i_intf']
    
    ts_v1_linear = results_emt_itm_linear[H_v_legends[i]]['v_1']
    ts_v2_linear = results_emt_itm_linear[H_v_legends[i]]['v_2_1']
    ts_i_intf_linear = results_emt_itm_linear[H_v_legends[i]]['i_intf']

    # if num_vs == 0:
    #     ts_1_m = results_emt[1]
    #     ts_2_m = results_emt[2]

    #     ts_1_zoh = results_emt_attributes_zoh[H_v_legends[i]][1]
    #     ts_2_zoh = results_emt_attributes_zoh[H_v_legends[i]][2]
        
    #     ts_1_linear = results_emt_attributes_linear_S1[H_v_legends[i]][1]
    #     ts_2_linear = results_emt_attributes_linear_S1[H_v_legends[i]][2]
    # else:
    #     ts_1_m = results_emt[2]
    #     ts_2_m = results_emt[3]
    
    #     ts_1_zoh = results_emt_attributes_zoh[H_v_legends[i]][2]
    #     ts_2_zoh = results_emt_attributes_zoh[H_v_legends[i]][3]
        
    #     ts_1_linear = results_emt_attributes_linear_S1[H_v_legends[i]][2]
    #     ts_2_linear = results_emt_attributes_linear_S1[H_v_legends[i]][3]
    
    xy_a = np.array([ts_v1_m.values[::m], ts_v2_m.values[::m], ts_i_intf_m.values[::m], ts_v2_m.values[::m]])
    # xy_zoh = np.array([ts_v1_zoh.values[::m], ts_v2_zoh.values[::m], ts_i_intf_zoh.values[::m], ts_v2_zoh.values[::m]])
    xy_linear = np.array([ts_v1_linear.values[::m], ts_v2_linear.values[::m], ts_i_intf_linear.values[::m], ts_v2_linear.values[::m]])
    
    # global_error_v1_zoh_t = np.abs(ts_v1_m.values[::m] - ts_v1_zoh.values[::m], axis=0)
    # global_error_v2_zoh_t = np.abs(ts_v2_m.values[::m] - ts_v2_zoh.values[::m], axis=0)
    # global_error_i_intf_zoh_t = np.abs(ts_i_intf_m.values[::m] - ts_i_intf_zoh.values[::m], axis=0)

    global_error_v1_linear_t = np.abs(ts_v1_m.values[::m] - ts_v1_linear.values[::m])
    global_error_v2_linear_t = np.abs(ts_v2_m.values[::m] - ts_v2_linear.values[::m])
    global_error_i_intf_linear_t = np.abs(ts_i_intf_m.values[::m] - ts_i_intf_linear.values[::m])
    
    # global_error_zoh_t = np.linalg.norm(xy_a - xy_zoh, axis=0)
    global_error_linear_t = np.linalg.norm(xy_a - xy_linear, axis=0)

    # plt.plot(ts_1_m.time[::m], gloal_error_zoh_t, label='ZOH - ' + H_v_legends[i])
    # plt.plot(ts_1_m.time[::m], gloal_error_linear_t, label='linear - ' + H_v_legends[i])

    axes[0].plot(ts_v1_m.time[::m], global_error_v1_linear_t, label='V1 - linear - ' + H_v_legends[i])
    axes[0].plot(ts_v2_m.time[::m], global_error_v2_linear_t, label='V2 - linear - ' + H_v_legends[i])

    axes[1].plot(ts_i_intf_m.time[::m], global_error_i_intf_linear_t, label='i_intf - linear - ' + H_v_legends[i])
    
    # global_error_zoh.append(np.max(global_error_zoh_t))
    global_error_linear.append(np.max(np.max(global_error_linear_t)))

axes[0].set_xlabel('t [s]')
axes[0].set_ylabel('Global error')
# plt.xlim((0, 0.4))
# plt.ylim((0.0008, 0.0012))
axes[0].grid()
axes[0].legend()

axes[1].set_xlabel('t [s]')
axes[1].set_ylabel('Global error')
# plt.xlim((0, 0.4))
# plt.ylim((0.0008, 0.0012))
axes[1].grid()
axes[1].legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
# plt.plot(np.log10(H_v), np.log10(global_error_zoh), 'b', label='ZOH')
# plt.plot(np.log10(H_v), np.log10(global_error_zoh), 'bo')
plt.plot(np.log10(H_v), np.log10(np.multiply(H_v, 10*0.012)), 'k', label=r'$\mathcal{O}(H)$')
plt.plot(np.log10(H_v), np.log10(global_error_linear), 'r', label='Linear')
plt.plot(np.log10(H_v), np.log10(global_error_linear), 'ro')
plt.plot(np.log10(H_v), np.log10(np.multiply(H_v**2, 10**1.5)), '--k', label=r'$\mathcal{O}(H^2)$')
# plt.plot(np.log10(H_v), np.log10(global_error_delay), 'g', label='Delay')
# plt.plot(np.log10(H_v), np.log10(global_error_delay), 'go')
plt.xlabel('')
plt.grid()
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
